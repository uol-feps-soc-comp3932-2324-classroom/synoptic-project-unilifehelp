# %%
import json
import gzip
import pandas as pd
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2164\840360880.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Importing metadata zip file and converting it to dataframe

def getDF(path):
  # Unzip the file, load in each line as an object
  g = gzip.open(path, 'rb')
  g = [json.loads(l) for l in g]

  # Map to a dictionary, then load in as a dataframe
  dict_df = {i: d for (i, d) in enumerate(g)}
  return pd.DataFrame.from_dict(dict_df, orient='index')

df = getDF('All_Beauty.json.gz')

# %%
# Identify all columns, their sizes and datatypes in json file 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 371345 entries, 0 to 371344
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         371345 non-null  float64
#  1   verified        371345 non-null  bool
#  2   reviewTime      371345 non-null  object
#  3   reviewerID      371345 non-null  object
#  4   asin            371345 non-null  object
#  5   reviewerName    371307 non-null  object
#  6   reviewText      370946 non-null  object
#  7   summary         371139 non-null  object
#  8   unixReviewTime  371345 non-null  int64
#  9   vote            51899 non-null   object
#  10  style           125958 non-null  object
#  11  image           8391 non-null    object
# dtypes: bool(1), float64(1), int64(1), object(9)
# memory usage: 34.4+ MB

# %%
df["reviewText"].describe()
# Out:
# count     370946
# unique    319643
# top         Good
# freq         802
# Name: reviewText, dtype: object

# %%
df
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0           1.0      True  02 19, 2015  A1V6B6TNIC10QE  0143026860
# 1           4.0      True  12 18, 2014  A2F5GHSXFQ0W6J  0143026860
# 2           4.0      True  08 10, 2014  A1572GUYS7DGSR  0143026860
# 3           5.0      True  03 11, 2013   A1PSGLFK1NSVO  0143026860
# 4           5.0      True  12 25, 2011   A6IKXKZMTKGSC  0143026860
# ...         ...       ...          ...             ...         ...
# 371340      1.0      True  07 20, 2017  A202DCI7TV1022  B01HJEGTYK
# 371341      5.0      True  03 16, 2017  A3FSOR5IJOFIBE  B01HJEGTYK
# 371342      5.0      True   03 1, 2017  A1B5DK6CTP2P24  B01HJEGTYK
# 371343      2.0      True  02 21, 2017  A23OUYS5IRMJS9  B01HJEGTYK
# 371344      2.0      True  12 15, 2016  A24KQ9RVU81L87  B01HJEGTYK
#
#              reviewerName                                         reviewText  \
# 0       theodore j bigham                                              great
# ...

# %%
# Find if there are any reviews that are empty
df_empty_reviews_index = (df["reviewText"] == "" )|( df["reviewText"].isnull())
print("Rows that have empty reviews")

df[df_empty_reviews_index]
# Out:
# Rows that have empty reviews
#         overall  verified   reviewTime      reviewerID        asin  \
# 547         5.0      True   03 4, 2017  A3TQJ5AQXW6CZH  1620213982
# 3594        5.0      True  05 21, 2015  A2CMCSBNYJETQY  1620213982
# 4105        5.0      True   01 7, 2015  A2W5DS4107108S  1620213982
# 6361        5.0      True  11 19, 2016  A2MZYX8PMNV32V  B000050FDY
# 6437        5.0      True  03 20, 2016   ACEV4EGUYH56O  B000050FDY
# ...         ...       ...          ...             ...         ...
# 369099      5.0      True  05 19, 2017  A16BQAEP3E5MAS  B01GOSELHE
# 369260      3.0      True  03 12, 2018  A1AXL15FT6ULO2  B01GQKM0AK
# 371092      5.0      True  03 12, 2018   A461O3V81H0GY  B01HEVYINM
# 371213      4.0      True  10 25, 2016  A2VYUF746IFMXJ  B01HHA8M8C
# 371296      5.0      True   06 7, 2017  A3T761GW3WVLED  B01HI75KNE
#
#            reviewerName reviewText                summary  unixReviewTime  \
# ...

# %%
df = df.drop(df[ ( (df["reviewText"] == "" ) | ( df["reviewText"].isnull()) ) ].index)

df
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0           1.0      True  02 19, 2015  A1V6B6TNIC10QE  0143026860
# 1           4.0      True  12 18, 2014  A2F5GHSXFQ0W6J  0143026860
# 2           4.0      True  08 10, 2014  A1572GUYS7DGSR  0143026860
# 3           5.0      True  03 11, 2013   A1PSGLFK1NSVO  0143026860
# 4           5.0      True  12 25, 2011   A6IKXKZMTKGSC  0143026860
# ...         ...       ...          ...             ...         ...
# 371340      1.0      True  07 20, 2017  A202DCI7TV1022  B01HJEGTYK
# 371341      5.0      True  03 16, 2017  A3FSOR5IJOFIBE  B01HJEGTYK
# 371342      5.0      True   03 1, 2017  A1B5DK6CTP2P24  B01HJEGTYK
# 371343      2.0      True  02 21, 2017  A23OUYS5IRMJS9  B01HJEGTYK
# 371344      2.0      True  12 15, 2016  A24KQ9RVU81L87  B01HJEGTYK
#
#              reviewerName                                         reviewText  \
# 0       theodore j bigham                                              great
# ...

# %%
# Selecting only the colums that are required for analysis

colums_reviewtext_asin = ["reviewText", "asin", "reviewerID"]
df = df[colums_reviewtext_asin]

df.describe()
# Out:
#        reviewText        asin      reviewerID
# count      370946      370946          370946
# unique     319643       32571          323687
# top          Good  B000FOI48G  A2GJX2KCUSR0EI
# freq          802        8671              27

# %%
# Identify range of values in reviews
df_reviews_without_empty = df["reviewText"].apply(lambda x: len(x.split()))
df_reviews_without_empty.describe()
# Out:
# count    319643.000000
# mean         42.042973
# std          59.966297
# min           1.000000
# 25%          11.000000
# 50%          24.000000
# 75%          49.000000
# max        2443.000000
# Name: reviewText, dtype: float64

# %%
# Check for innapropriate characters in review column

import re

# Check for non alphabetic or alphanumeric instances in reviews using Regex (in each review)
df["characters_in_review"] = df["reviewText"].apply(lambda x: set(re.findall(r'[^A-Za-z0-9\s]', x)))
df
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2164\1459922655.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["characters_in_review"] = df["reviewText"].apply(lambda x: set(re.findall(r'[^A-Za-z0-9\s]', x)))
#                                                reviewText        asin  \
# 0                                                   great  0143026860
# 1       My  husband wanted to reading about the Negro ...  0143026860
# 2       This book was very informative, covering all a...  0143026860
# 3       I am already a baseball fan and knew a bit abo...  0143026860
# 4       This was a good story of the Black leagues. I ...  0143026860
# ...                                                   ...         ...
# ...

# %%
unnecessary_characters = set()
for x in df["characters_in_review"]:
    unnecessary_characters = unnecessary_characters.union(x)
print("All unecessy characters in reviews column:", unnecessary_characters)

# Need to be careful as there are \' in text
# Out:
# All unecessy characters in description column: {')', '_', '~', '*', '+', '"', '\\', '{', '}', '<', '`', ']', '>', '?', '^', '!', '\x10', ';', "'", '@', '(', '/', '[', '%', '&', '=', '#', '-', '|', ':', ',', '.', '\x7f', '$'}

# %%
# Identify top words that come up in reviews 

from collections import Counter
Counter(" ".join(df["reviewText"]).split()).most_common(100)
# Out:
# [('I', 533485),
#  ('the', 511606),
#  ('and', 417879),
#  ('a', 352114),
#  ('to', 326615),
#  ('it', 298263),
#  ('is', 214670),
#  ('my', 208628),
#  ('for', 191118),
#  ('this', 186466),
#  ('of', 177589),
#  ('in', 129628),
#  ('that', 115835),
#  ('have', 114987),
#  ('but', 111737),
#  ('on', 109942),
#  ('with', 108796),
#  ('was', 100655),
#  ('not', 98123),
#  ('as', 84257),
#  ('you', 79395),
#  ('The', 77691),
#  ('so', 75939),
#  ('It', 75384),
#  ('like', 66449),
#  ('very', 64760),
#  ('are', 64399),
#  ('product', 63063),
#  ('This', 60854),
#  ('use', 60179),
#  ('be', 51926),
#  ('just', 46037),
#  ('at', 45968),
#  ('one', 45262),
#  ('or', 44979),
#  ('hair', 44544),
#  ('great', 43131),
#  ('your', 42147),
#  ('love', 41416),
#  ('they', 41261),
#  ('good', 41120),
#  ('will', 41068),
#  ('all', 39849),
#  ('really', 39522),
#  ('would', 39316),
#  ('had', 38908),
#  ('get', 38727),
#  ('has', 37205),
#  ('skin', 37107),
#  ('than', 37023),
#  ('it.', 36522),
# ...

# %%
# Identify duplicate reviews where asin, reviewText and reviewID is the same (written by the same person)
duplicate_list = ["reviewText", "asin", "reviewerID"]

duplicated_rows = df.duplicated(duplicate_list, keep = False)
df[duplicated_rows].sort_values(duplicate_list)

df= df.drop_duplicates(duplicate_list, keep = "last")
df

# 370940 - 362180 identified
# There are more duplicates left (since there are more unique reviews identified) 
# which means some custumers left the same reviews and those need to be removed at the cleanin stage
# Out:
#                                                reviewText        asin  \
# 0                                                   great  0143026860
# 1       My  husband wanted to reading about the Negro ...  0143026860
# 2       This book was very informative, covering all a...  0143026860
# 3       I am already a baseball fan and knew a bit abo...  0143026860
# 4       This was a good story of the Black leagues. I ...  0143026860
# ...                                                   ...         ...
# 371340  It was awful. It was super frizzy and I tried ...  B01HJEGTYK
# 371341  I was skeptical about buying this.  Worried it...  B01HJEGTYK
# 371342                           Makes me look good fast.  B01HJEGTYK
# 371343  Way lighter than photo\nNot mix blend of color...  B01HJEGTYK
# 371344  No return instructions/phone # in packaging.  ...  B01HJEGTYK
#
#             reviewerID characters_in_review
# 0       A1V6B6TNIC10QE                   {}
# ...

# %%
# Remove duplicate reviews
df[df.duplicated("reviewText")]
df = df.drop_duplicates("reviewText", keep="last")
df.describe()
# Out:
#                                                reviewText        asin  \
# count                                              319643      319643
# unique                                             319643       31438
# top     My  husband wanted to reading about the Negro ...  B000FOI48G
# freq                                                    1        8268
#
#             reviewerID characters_in_review
# count           319643               319643
# unique          299718                 5694
# top     A2GJX2KCUSR0EI                  {.}
# freq                25                64560

# %%
# ASIN analysis

asin = df["asin"].apply(lambda x: len(x))

# Check for lengths of asins by CHARACTER
asin.describe()
# Out:
# count    362180.0
# mean         10.0
# std           0.0
# min          10.0
# 25%          10.0
# 50%          10.0
# 75%          10.0
# max          10.0
# Name: asin, dtype: float64

# %%
# Check for innapropriate characters in asin column

# Check for non alphabetic(uppercase) or alphanumeric instances in the whole asin column using Regex
df["characters_in_asin"] = df["asin"].apply(lambda x: set(re.findall(r'[^A-Z0-9\s]', x)))

unnecessary_asin_characters = set()
for x in df["characters_in_asin"]:
    unnecessary_asin_characters = unnecessary_asin_characters.union(x)
print("There are no unecessy characters in asin column:", unnecessary_asin_characters)
# Out:
# There are no unecessy characters in asin column: set()
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_37568\3412770196.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["characters_in_asin"] = df["asin"].apply(lambda x: set(re.findall(r'[^A-Z0-9\s]', x)))
